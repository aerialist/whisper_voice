# %%
from pathlib import Path

import yaml
import openai
import pandas as pd

# %%
from dotenv import load_dotenv
load_dotenv()  # Load environment variables from .env file
# Out:
# True

# %%
client = openai.OpenAI()

# %%
p = Path('recordings')

# %%
throat_small = sorted(list(p.glob('External_Microphone/*.wav')))

# %%
len(throat_small)
# Out:
# 100

# %%
throat_small[0]
# Out:
# PosixPath('recordings/External_Microphone/20251021232813.wav')

# %%
throat_small_enhanced = sorted(list(p.glob('External_Microphone_Enhanced/*.wav')))

# %%
len(throat_small_enhanced)
# Out:
# 100

# %%
throat_large = sorted(list(p.glob('GHW_USB_AUDIO/*.wav')))

# %%
len(throat_large)
# Out:
# 100

# %%
throat_large_enhanced = sorted(list(p.glob('GHW_USB_AUDIO_Enhanced/*.wav')))

# %%
throat_small_enhanced_LJ_V1 = sorted(list(p.glob('External_Microphone_Enhanced_LJ_V1/*.wav')))
throat_small_enhanced_VCTK_V1 = sorted(list(p.glob('External_Microphone_Enhanced_VCTK_V1/*.wav')))
throat_small_enhanced_UNIVERSAL_V1 = sorted(list(p.glob('External_Microphone_Enhanced_UNIVERSAL_V1/*.wav')))
throat_large_enhanced_LJ_V1 = sorted(list(p.glob('GHW_USB_AUDIO_Enhanced_LJ_V1/*.wav')))
throat_large_enhanced_VCTK_V1 = sorted(list(p.glob('GHW_USB_AUDIO_Enhanced_VCTK_V1/*.wav')))
throat_large_enhanced_UNIVERSAL_V1 = sorted(list(p.glob('GHW_USB_AUDIO_Enhanced_UNIVERSAL_V1/*.wav')))

# %%
reference_mic = sorted(list(p.glob('Marantz_Umpire_Mic/*.wav')))

# %%
len(reference_mic)
# Out:
# 100

# %%
with Path('basic5000.yaml').open('r') as f:
    basic5000 = yaml.safe_load(f)

# %%
basic5000['BASIC5000_0001']['text_level0']
# Out:
# '水をマレーシアから買わなくてはならないのです。'

# %%
correct_texts = []
for i in range(1, 101):
    key = f"BASIC5000_{i:04d}"
    correct_texts.append(basic5000[key]['text_level0'])

# %%
def transcribe_sync_from_file(file_path):
    with open(file_path, "rb") as audio_file:
        transcript = client.audio.transcriptions.create(
            model="whisper-1",
            file=audio_file,
            language="ja",
            temperature=0.2,
        )

    return transcript.text

# %%
correct_texts[0]
# Out:
# '水をマレーシアから買わなくてはならないのです。'

# %%
transcribe_sync_from_file(reference_mic[0])
# Out:
# '水をマレーシアから買わなくてはならないのです。'

# %%
transcribe_sync_from_file(throat_small[0])
# Out:
# 'いつもマレーシアから買わなくてはならないのです。'

# %%
transcribe_sync_from_file(throat_small_enhanced[0])
# Out:
# 'いつも、毎日、やからかは、乗ってはならないのです。'

# %%
transcribe_sync_from_file(throat_large[0])
# Out:
# '別でマレーシアからカンパウンドのような音です。'

# %%
transcribe_sync_from_file(throat_large_enhanced[0])
# Out:
# '肉を焼きしながら食べます。'

# %%
df = pd.DataFrame({
    'correct_text': correct_texts,
    'reference_mic': reference_mic,
    'throat_small': throat_small,
    'throat_small_enhanced': throat_small_enhanced,
    'throat_small_enhanced_LJ_V1': throat_small_enhanced_LJ_V1,
    'throat_small_enhanced_VCTK_V1': throat_small_enhanced_VCTK_V1,
    'throat_small_enhanced_UNIVERSAL_V1': throat_small_enhanced_UNIVERSAL_V1,
    'throat_large': throat_large,
    'throat_large_enhanced': throat_large_enhanced,
    'throat_large_enhanced_LJ_V1': throat_large_enhanced_LJ_V1,
    'throat_large_enhanced_VCTK_V1': throat_large_enhanced_VCTK_V1,
    'throat_large_enhanced_UNIVERSAL_V1': throat_large_enhanced_UNIVERSAL_V1,
})

# %%
df['reference_mic_transcript'] = df['reference_mic'].apply(transcribe_sync_from_file)
df['throat_small_transcript'] = df['throat_small'].apply(transcribe_sync_from_file)
df['throat_small_enhanced_transcript'] = df['throat_small_enhanced'].apply(transcribe_sync_from_file)
df['throat_small_enhanced_LJ_V1_transcript'] = df['throat_small_enhanced_LJ_V1'].apply(transcribe_sync_from_file)
df['throat_small_enhanced_VCTK_V1_transcript'] = df['throat_small_enhanced_VCTK_V1'].apply(transcribe_sync_from_file)
df['throat_small_enhanced_UNIVERSAL_V1_transcript'] = df['throat_small_enhanced_UNIVERSAL_V1'].apply(transcribe_sync_from_file)
df['throat_large_transcript'] = df['throat_large'].apply(transcribe_sync_from_file)
df['throat_large_enhanced_transcript'] = df['throat_large_enhanced'].apply(transcribe_sync_from_file)
df['throat_large_enhanced_LJ_V1_transcript'] = df['throat_large_enhanced_LJ_V1'].apply(transcribe_sync_from_file)
df['throat_large_enhanced_VCTK_V1_transcript'] = df['throat_large_enhanced_VCTK_V1'].apply(transcribe_sync_from_file)
df['throat_large_enhanced_UNIVERSAL_V1_transcript'] = df['throat_large_enhanced_UNIVERSAL_V1'].apply(transcribe_sync_from_file)

# %%
df.to_pickle('throat2air_sklearn_result_hifi-gan.pkl')

# %%
df.head()
# Out:
#                  correct_text  \
# 0     水をマレーシアから買わなくてはならないのです。
# 1  木曜日、停戦会談は、何の進展もないまま終了しました。
# 2       上院議員は私がデータをゆがめたと告発した。
# 3        １週間して、そのニュースは本当になった。
# 4      血圧は、健康のパロメーターとして重要である。
#
#                                       reference_mic  \
# 0  recordings/Marantz_Umpire_Mic/20251021232813.wav
# 1  recordings/Marantz_Umpire_Mic/20251021233140.wav
# 2  recordings/Marantz_Umpire_Mic/20251021233208.wav
# 3  recordings/Marantz_Umpire_Mic/20251021233250.wav
# 4  recordings/Marantz_Umpire_Mic/20251021233319.wav
#
#                                         throat_small  \
# 0  recordings/External_Microphone/20251021232813.wav
# 1  recordings/External_Microphone/20251021233140.wav
# 2  recordings/External_Microphone/20251021233208.wav
# 3  recordings/External_Microphone/20251021233250.wav
# 4  recordings/External_Microphone/20251021233319.wav
#
#                                throat_small_enhanced  \
# 0  recordings/External_Microphone_Enhanced/202510...
# 1  recordings/External_Microphone_Enhanced/202510...
# 2  recordings/External_Microphone_Enhanced/202510...
# 3  recordings/External_Microphone_Enhanced/202510...
# 4  recordings/External_Microphone_Enhanced/202510...
#
#                          throat_small_enhanced_LJ_V1  \
# 0  recordings/External_Microphone_Enhanced_LJ_V1/...
# 1  recordings/External_Microphone_Enhanced_LJ_V1/...
# 2  recordings/External_Microphone_Enhanced_LJ_V1/...
# 3  recordings/External_Microphone_Enhanced_LJ_V1/...
# 4  recordings/External_Microphone_Enhanced_LJ_V1/...
#
#                        throat_small_enhanced_VCTK_V1  \
# 0  recordings/External_Microphone_Enhanced_VCTK_V...
# 1  recordings/External_Microphone_Enhanced_VCTK_V...
# 2  recordings/External_Microphone_Enhanced_VCTK_V...
# 3  recordings/External_Microphone_Enhanced_VCTK_V...
# 4  recordings/External_Microphone_Enhanced_VCTK_V...
#
#                   throat_small_enhanced_UNIVERSAL_V1  \
# 0  recordings/External_Microphone_Enhanced_UNIVER...
# 1  recordings/External_Microphone_Enhanced_UNIVER...
# 2  recordings/External_Microphone_Enhanced_UNIVER...
# 3  recordings/External_Microphone_Enhanced_UNIVER...
# 4  recordings/External_Microphone_Enhanced_UNIVER...
#
#                                   throat_large  \
# 0  recordings/GHW_USB_AUDIO/20251021232813.wav
# 1  recordings/GHW_USB_AUDIO/20251021233140.wav
# 2  recordings/GHW_USB_AUDIO/20251021233208.wav
# 3  recordings/GHW_USB_AUDIO/20251021233250.wav
# 4  recordings/GHW_USB_AUDIO/20251021233319.wav
#
#                                throat_large_enhanced  \
# 0  recordings/GHW_USB_AUDIO_Enhanced/202510212328...
# 1  recordings/GHW_USB_AUDIO_Enhanced/202510212331...
# 2  recordings/GHW_USB_AUDIO_Enhanced/202510212332...
# 3  recordings/GHW_USB_AUDIO_Enhanced/202510212332...
# 4  recordings/GHW_USB_AUDIO_Enhanced/202510212333...
#
#                          throat_large_enhanced_LJ_V1  ...  \
# 0  recordings/GHW_USB_AUDIO_Enhanced_LJ_V1/202510...  ...
# 1  recordings/GHW_USB_AUDIO_Enhanced_LJ_V1/202510...  ...
# 2  recordings/GHW_USB_AUDIO_Enhanced_LJ_V1/202510...  ...
# 3  recordings/GHW_USB_AUDIO_Enhanced_LJ_V1/202510...  ...
# 4  recordings/GHW_USB_AUDIO_Enhanced_LJ_V1/202510...  ...
#
#      throat_small_transcript throat_small_enhanced_transcript  \
# 0   いつもマレーシアから買わなくてはならないのです。          いつも、毎日、柔らかは乗ってはならないのです。
# 1  木曜日、停線階段は何の進展もないまま終了しました。        木曜日、停線改段は何の進展もないまま終了しました。
# 2       上院議員は私がデータを歪めたと告発した。             教員入院は私がデータを歪めたと告発した。
# 3         一週間してそのニュースは本当になった              一週間してそのニュースは本当になった。
# 4       血圧は健康のバロメータとして重要である。          血圧は健康のバロンウィーカーとして重要である。
#
#   throat_small_enhanced_LJ_V1_transcript  \
# 0               リズムを真似しながら噛まなくてはならないのです。
# 1             木曜日、定前会談は、何の進展もないまま終了しました。
# 2                    病院院員は私がデータを歪めたと告発した
# 3                     一週間してそのニュースは本当になった
# 4                   血圧は健康のバラエティとして重要である。
#
#   throat_small_enhanced_VCTK_V1_transcript  \
# 0                   水を招きしやかなかまなくてはならないのです。
# 1                木曜日、停線階段は何の進展もないまま終了しました。
# 2                     調理人員は私がデータを歪めたと告発した。
# 3                       一週間してそのニュースは本当になった
# 4                    血圧は健康のバロルエータとして重要である。
#
#   throat_small_enhanced_UNIVERSAL_V1_transcript  throat_large_transcript  \
# 0                        水を招いてしやかな顔なくてはならないのです。  別でマレーシアからカナダの方への呼びかけです。
# 1                     木曜日、停船階段は段の進展がないまま終了しました。  木曜日、定山会談はこの進展のみを終了しました。
# 2                          教員議員は私がデータを歪めたと告発した。  JMGはあたしのデータを入れ替えたと伝発した。
# 3                            一週間してそのニュースは本当になった  一生懸命して、そのネオイスは本当にいなかった。
# 4                        血圧は健康のバロリエーターとして重要である。     客さんさん、健康のために隠して重要です。
#
#        throat_large_enhanced_transcript  \
# 0                         肉を骨にしながら食べます。
# 1  木曜日、テースラル会談はパワーシンティアの 今後の次期をお知らせします。
# 2                 教員の指輪には同じな結果を得たと報告した。
# 3                     一周して、この状況は安保になった。
# 4                     徹末は結構あままに隠してきようやん
#
#   throat_large_enhanced_LJ_V1_transcript  \
# 0                にもダメージがかからなくてはならないようです。
# 1       木曜日、手休み会談は、まもなく、このままには待ちきれはしました。
# 2          病院に入院は私が出たお気に入りコンパクトグラフィックでした
# 3                         ご視聴ありがとうございました
# 4                         ご視聴ありがとうございました
#
#   throat_large_enhanced_VCTK_V1_transcript  \
# 0                  水をなでにしていただかなくてはならないのです。
# 1            木曜日、低層階段は、あの終点のままには待ち入れをしました。
# 2                    教員のみんな私の中に遠い日が来たと告白した
# 3                  一瞬くらいの時間で、さまよい歯は半端になった。
# 4                 こいつはつまんない子を守るメイクとして重要である
#
#   throat_large_enhanced_UNIVERSAL_V1_transcript
# 0                       リブをマネーして、ふかなくてはならないのです。
# 1                     木曜日、低層階段はこの進展のないまま終了しました。
# 2                             教員は私のネットを指噛むと告白した
# 3                            一瞬くらいしてその迷惑は本当になった
# 4                        いつもやつは最高のバドミンカとして重要である
#
# [5 rows x 23 columns]

# %%
# pip install openai python-dotenv tqdm pandas tenacity orjson
import os, json, orjson, time
from dataclasses import dataclass
from typing import Dict, Any, List
import pandas as pd
from tenacity import retry, stop_after_attempt, wait_exponential, retry_if_exception_type
from tqdm import tqdm
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

PROMPT_TMPL = """あなたは日本語ASRの評価者です。出力は必ず有効なJSONのみ。

## 目的
正解テキスト（漢字かな混在）と、各方式の転写結果（reference_mic, throat_small, throat_small_enhanced, throat_large, throat_large_enhanced）を比較し、以下の5段階で意味を最重視して採点します。

## 採点基準（意味を強く反映）
1: 意味が全く合わない（主述/極性/要点が不一致。伝達失敗）
2: 話題は拾えている（トピック近いが要点がズレる/誤情報あり）
3: なんとか意味は通じる（要点は概ね合うが誤り/欠落が目立つ）
4: 表記ゆれ/誤変換はあるが意味は明瞭（情報保持は十分）
5: ほぼ正解と同じ（軽微な表記差のみ）

### 減点の指針
- 重大誤りは大減点：否定/極性の取り違え、数量・固有名詞の誤り、主語述語の取り違え
- 軽微な減点：漢字↔かなの違い、仮名ゆれ、句読点・長音の揺れ、同義語置換
- 同音異義は文脈で意味が変わるなら減点

### 出力形式（JSONのみ）
{{
  "reference_mic": {{"score": <1-5の整数>, "reason_ja": "<40字以内>"}},
  "throat_small": {{"score": <1-5>, "reason_ja": "<40字以内>"}},
  "throat_small_enhanced": {{"score": <1-5>, "reason_ja": "<40字以内>"}},
  "throat_small_enhanced_LJ_V1": {{"score": <1-5>, "reason_ja": "<40字以内>"}},
  "throat_small_enhanced_VCTK_V1": {{"score": <1-5>, "reason_ja": "<40字以内>"}},
  "throat_small_enhanced_UNIVERSAL_V1": {{"score": <1-5>, "reason_ja": "<40字以内>"}},
  "throat_large": {{"score": <1-5>, "reason_ja": "<40字以内>"}},
  "throat_large_enhanced": {{"score": <1-5>, "reason_ja": "<40字以内>"}},
  "throat_large_enhanced_LJ_V1": {{"score": <1-5>, "reason_ja": "<40字以内>"}},
  "throat_large_enhanced_VCTK_V1": {{"score": <1-5>, "reason_ja": "<40字以内>"}},
  "throat_large_enhanced_UNIVERSAL_V1": {{"score": <1-5>, "reason_ja": "<40字以内>"}}
}}

## 入力
[正解テキスト]
{correct_text}

[各方式の転写結果]
- reference_mic: {reference_mic_transcript}
- throat_small: {throat_small_transcript}
- throat_small_enhanced: {throat_small_enhanced_transcript}
- throat_small_enhanced_LJ_V1: {throat_small_enhanced_LJ_V1_transcript}
- throat_small_enhanced_VCTK_V1: {throat_small_enhanced_VCTK_V1_transcript}
- throat_small_enhanced_UNIVERSAL_V1: {throat_small_enhanced_UNIVERSAL_V1_transcript}
- throat_large: {throat_large_transcript}
- throat_large_enhanced: {throat_large_enhanced_transcript}
- throat_large_enhanced_LJ_V1: {throat_large_enhanced_LJ_V1_transcript}
- throat_large_enhanced_VCTK_V1: {throat_large_enhanced_VCTK_V1_transcript}
- throat_large_enhanced_UNIVERSAL_V1: {throat_large_enhanced_UNIVERSAL_V1_transcript}

## 注意
- 出力はJSONのみ。説明文やマークダウンは禁止。
- 判定は意味最優先。表記差は軽減。
- 不明・空欄は「1〜2」を基準に、理由に「欠落」と明記。
"""

@dataclass
class Item:
    # 1発話分のバンドル
    correct_text: str
    reference_mic_transcript: str
    throat_small_transcript: str
    throat_small_enhanced_transcript: str  # ←綴り注意: trascriptではなくtranscript
    throat_small_enhanced_LJ_V1_transcript: str
    throat_small_enhanced_VCTK_V1_transcript: str
    throat_small_enhanced_UNIVERSAL_V1_transcript: str
    throat_large_transcript: str
    throat_large_enhanced_transcript: str
    throat_large_enhanced_LJ_V1_transcript: str
    throat_large_enhanced_VCTK_V1_transcript: str
    throat_large_enhanced_UNIVERSAL_V1_transcript: str
    uid: str  # 識別子（ファイル名等）

def build_prompt(item: Item) -> str:
    # 多少のNoneや空文字に頑健化
    def nz(x): return "" if x is None else str(x)
    return PROMPT_TMPL.format(
        correct_text=nz(item.correct_text),
        reference_mic_transcript=nz(item.reference_mic_transcript),
        throat_small_transcript=nz(item.throat_small_transcript),
        throat_small_enhanced_transcript=nz(item.throat_small_enhanced_transcript),
        throat_small_enhanced_LJ_V1_transcript=nz(item.throat_small_enhanced_LJ_V1_transcript),
        throat_small_enhanced_VCTK_V1_transcript=nz(item.throat_small_enhanced_VCTK_V1_transcript),
        throat_small_enhanced_UNIVERSAL_V1_transcript=nz(item.throat_small_enhanced_UNIVERSAL_V1_transcript),
        throat_large_transcript=nz(item.throat_large_transcript),
        throat_large_enhanced_transcript=nz(item.throat_large_enhanced_transcript),
        throat_large_enhanced_LJ_V1_transcript=nz(item.throat_large_enhanced_LJ_V1_transcript),
        throat_large_enhanced_VCTK_V1_transcript=nz(item.throat_large_enhanced_VCTK_V1_transcript),
        throat_large_enhanced_UNIVERSAL_V1_transcript=nz(item.throat_large_enhanced_UNIVERSAL_V1_transcript),
    )

class JSONParseError(Exception):
    pass

def safe_json_loads(s: str) -> Dict[str, Any]:
    # 余計な前後テキストの除去＆厳格パース
    s = s.strip()
    # JSON以外の行を落とす（最外カッコ抽出）
    first = s.find("{")
    last = s.rfind("}")
    if first == -1 or last == -1:
        raise JSONParseError("No JSON object braced by { } found.")
    core = s[first:last+1]
    try:
        return orjson.loads(core)
    except Exception as e:
        # よくある末尾カンマ等の修正はしない（評価の厳格性を維持）
        raise JSONParseError(str(e))

@retry(
    reraise=True,
    stop=stop_after_attempt(3),
    wait=wait_exponential(multiplier=1, min=1, max=8),
    retry=retry_if_exception_type((JSONParseError, Exception))
)
def score_with_gpt(item: Item, model: str = "gpt-5") -> Dict[str, Any]:
    prompt = build_prompt(item)
    resp = client.chat.completions.create(
        model=model,
        #temperature=0.2,
        top_p=1.0,
        messages=[{"role": "user", "content": prompt}],
        # JSON強制モード（対応モデルなら有効）
        response_format={"type": "json_object"}
    )
    text = resp.choices[0].message.content
    data = safe_json_loads(text)
    # 必須キーが無ければ例外（→retry）
    required = [
        "reference_mic",
        "throat_small","throat_small_enhanced","throat_small_enhanced_LJ_V1","throat_small_enhanced_VCTK_V1","throat_small_enhanced_UNIVERSAL_V1",
        "throat_large","throat_large_enhanced","throat_large_enhanced_LJ_V1","throat_large_enhanced_VCTK_V1","throat_large_enhanced_UNIVERSAL_V1"
    ]
    for k in required:
        if k not in data or "score" not in data[k]:
            raise JSONParseError(f"Missing key/score: {k}")
    return data

def flatten_result(uid: str, correct_text: str, result: Dict[str, Any]) -> Dict[str, Any]:
    row = {"uid": uid, "correct_text": correct_text}
    for system in ["reference_mic","throat_small","throat_small_enhanced","throat_small_enhanced_LJ_V1","throat_small_enhanced_VCTK_V1","throat_small_enhanced_UNIVERSAL_V1","throat_large","throat_large_enhanced","throat_large_enhanced_LJ_V1","throat_large_enhanced_VCTK_V1","throat_large_enhanced_UNIVERSAL_V1"]:
        row[f"{system}_score"]  = int(result[system]["score"])
        row[f"{system}_reason"] = result[system].get("reason_ja","")
    return row

def summarize(df: pd.DataFrame) -> pd.DataFrame:
    cols = [c for c in df.columns if c.endswith("_score")]
    mean = df[cols].mean().to_frame("mean_score")
    std  = df[cols].std(ddof=1).to_frame("std")
    cnt  = df[cols].count().to_frame("n")
    summary = mean.join(std).join(cnt)
    summary["rank"] = summary["mean_score"].rank(ascending=False, method="min")
    return summary.sort_values("mean_score", ascending=False)

# %%
df.columns
# Out:
# Index(['correct_text', 'reference_mic', 'throat_small',
#        'throat_small_enhanced', 'throat_small_enhanced_LJ_V1',
#        'throat_small_enhanced_VCTK_V1', 'throat_small_enhanced_UNIVERSAL_V1',
#        'throat_large', 'throat_large_enhanced', 'throat_large_enhanced_LJ_V1',
#        'throat_large_enhanced_VCTK_V1', 'throat_large_enhanced_UNIVERSAL_V1',
#        'reference_mic_transcript', 'throat_small_transcript',
#        'throat_small_enhanced_transcript',
#        'throat_small_enhanced_LJ_V1_transcript',
#        'throat_small_enhanced_VCTK_V1_transcript',
#        'throat_small_enhanced_UNIVERSAL_V1_transcript',
#        'throat_large_transcript', 'throat_large_enhanced_transcript',
#        'throat_large_enhanced_LJ_V1_transcript',
#        'throat_large_enhanced_VCTK_V1_transcript',
#        'throat_large_enhanced_UNIVERSAL_V1_transcript'],
#       dtype='object')

# %%
flats = []
for row in df.itertuples():
    item = Item(
        correct_text = row.correct_text,
        reference_mic_transcript = row.reference_mic_transcript,
        throat_small_transcript = row.throat_small_transcript,
        throat_small_enhanced_transcript = row.throat_small_enhanced_transcript,
        throat_small_enhanced_LJ_V1_transcript = row.throat_small_enhanced_LJ_V1_transcript,
        throat_small_enhanced_VCTK_V1_transcript = row.throat_small_enhanced_VCTK_V1_transcript,
        throat_small_enhanced_UNIVERSAL_V1_transcript = row.throat_small_enhanced_UNIVERSAL_V1_transcript,
        throat_large_transcript = row.throat_large_transcript,
        throat_large_enhanced_transcript = row.throat_large_enhanced_transcript,
        throat_large_enhanced_LJ_V1_transcript = row.throat_large_enhanced_LJ_V1_transcript,
        throat_large_enhanced_VCTK_V1_transcript = row.throat_large_enhanced_VCTK_V1_transcript,
        throat_large_enhanced_UNIVERSAL_V1_transcript = row.throat_large_enhanced_UNIVERSAL_V1_transcript,
        uid = f"item_{row.Index+1:04d}"
    )
    result = score_with_gpt(item, model="gpt-5")
    flat = flatten_result(item.uid, item.correct_text, result)
    flats.append(flat)
    #print(flat)
    #break  # 最初の1件だけ試す

# %%
df_score = pd.DataFrame(flats)
df_summary = summarize(df_score)

# %%
df_score.head()
# Out:
#          uid                correct_text  reference_mic_score  \
# 0  item_0001     水をマレーシアから買わなくてはならないのです。                    5
# 1  item_0002  木曜日、停戦会談は、何の進展もないまま終了しました。                    4
# 2  item_0003       上院議員は私がデータをゆがめたと告発した。                    5
# 3  item_0004        １週間して、そのニュースは本当になった。                    5
# 4  item_0005      血圧は、健康のパロメーターとして重要である。                    5
#
#   reference_mic_reason  throat_small_score throat_small_reason  \
# 0                原文と一致                   3   対象（水）が欠落、義務と産地は一致
# 1   停戦会談→誤字だが無進展で終了は一致                   4  停戦会談→誤字だが無進展で終了は一致
# 2           表記差のみで意味一致                   5          表記差のみで意味一致
# 3         数字表記差のみで完全一致                   5        句読点欠如のみで意味一致
# 4           表記差のみで意味一致                   5          表記差のみで意味一致
#
#    throat_small_enhanced_score throat_small_enhanced_reason  \
# 0                            1                 否定命令に転倒し意味崩壊
# 1                            3            主語が崩れ不明確、無進展終了は維持
# 2                            3                   主語誤りだが要点一致
# 3                            5                  句読点差のみで意味一致
# 4                            3             キーワード崩れも、重要性は伝わる
#
#    throat_small_enhanced_LJ_V1_score throat_small_enhanced_LJ_V1_reason  ...  \
# 0                                  1                        目的語・動作ともに別物  ...
# 1                                  4                     会談は正しく無進展終了も一致  ...
# 2                                  3                          主語の固有名詞誤り  ...
# 3                                  5                        句読点差のみで意味一致  ...
# 4                                  2                       「バラエティ」で要点逸脱  ...
#
#    throat_large_score throat_large_reason  throat_large_enhanced_score  \
# 0                   1         全く別内容。要点不一致                            1
# 1                   1     無進展の意味が崩れ、要点不一致                            1
# 2                   1        主語・述語・内容が不一致                            1
# 3                   1         誤語・否定で意味不一致                            1
# 4                   1           意味不一致・無関係                            1
#
#   throat_large_enhanced_reason  throat_large_enhanced_LJ_V1_score  \
# 0                       無関係な内容                                  1
# 1             内容が大きく逸脱し意味が合わない                                  1
# 2                    内容が大きく異なる                                  1
# 3                要点ズレ・語義不明で不一致                                  1
# 4                      意味崩壊・欠落                                  1
#
#   throat_large_enhanced_LJ_V1_reason  throat_large_enhanced_VCTK_V1_score  \
# 0                          無関係、要点不一致                                    2
# 1                   意味が通らず主題・要点の伝達失敗                                    1
# 2                         意味不明で要点不一致                                    1
# 3                      別内容の定型文で全く不一致                                    1
# 4                        無関係の挨拶で意味欠落                                    1
#
#   throat_large_enhanced_VCTK_V1_reason  \
# 0                       水はあるが意味不明、産地欠落
# 1                       内容破綻。主題・要点が不一致
# 2                          告発→告白など意味破綻
# 3                          意味破綻し話題も不一致
# 4                          無関係内容で意味不一致
#
#    throat_large_enhanced_UNIVERSAL_V1_score  \
# 0                                         1
# 1                                         3
# 2                                         1
# 3                                         2
# 4                                         1
#
#   throat_large_enhanced_UNIVERSAL_V1_reason
# 0                                  無関係で要点欠落
# 1                          主語誤りだが無進展で終了は伝わる
# 2                                意味不明で要点不一致
# 3                             時間・主題誤りで要点不一致
# 4                               無関係内容で意味不一致
#
# [5 rows x 24 columns]

# %%
df_summary
# Out:
#                                           mean_score       std    n  rank
# reference_mic_score                             4.57  0.890522  100   1.0
# throat_small_score                              2.90  1.452966  100   2.0
# throat_small_enhanced_VCTK_V1_score             2.42  1.357210  100   3.0
# throat_small_enhanced_UNIVERSAL_V1_score        2.39  1.324936  100   4.0
# throat_large_score                              2.33  1.557355  100   5.0
# throat_large_enhanced_VCTK_V1_score             1.96  1.154001  100   6.0
# throat_small_enhanced_LJ_V1_score               1.88  1.241374  100   7.0
# throat_large_enhanced_UNIVERSAL_V1_score        1.88  1.174476  100   7.0
# throat_large_enhanced_LJ_V1_score               1.69  1.088925  100   9.0
# throat_small_enhanced_score                     1.55  0.957427  100  10.0
# throat_large_enhanced_score                     1.46  0.989031  100  11.0

# %%
df_with_score =pd.concat([df, df_score], axis=1)

# %%
df_with_score.head()
# Out:
#                  correct_text  \
# 0     水をマレーシアから買わなくてはならないのです。
# 1  木曜日、停戦会談は、何の進展もないまま終了しました。
# 2       上院議員は私がデータをゆがめたと告発した。
# 3        １週間して、そのニュースは本当になった。
# 4      血圧は、健康のパロメーターとして重要である。
#
#                                       reference_mic  \
# 0  recordings/Marantz_Umpire_Mic/20251021232813.wav
# 1  recordings/Marantz_Umpire_Mic/20251021233140.wav
# 2  recordings/Marantz_Umpire_Mic/20251021233208.wav
# 3  recordings/Marantz_Umpire_Mic/20251021233250.wav
# 4  recordings/Marantz_Umpire_Mic/20251021233319.wav
#
#                                         throat_small  \
# 0  recordings/External_Microphone/20251021232813.wav
# 1  recordings/External_Microphone/20251021233140.wav
# 2  recordings/External_Microphone/20251021233208.wav
# 3  recordings/External_Microphone/20251021233250.wav
# 4  recordings/External_Microphone/20251021233319.wav
#
#                                throat_small_enhanced  \
# 0  recordings/External_Microphone_Enhanced/202510...
# 1  recordings/External_Microphone_Enhanced/202510...
# 2  recordings/External_Microphone_Enhanced/202510...
# 3  recordings/External_Microphone_Enhanced/202510...
# 4  recordings/External_Microphone_Enhanced/202510...
#
#                          throat_small_enhanced_LJ_V1  \
# 0  recordings/External_Microphone_Enhanced_LJ_V1/...
# 1  recordings/External_Microphone_Enhanced_LJ_V1/...
# 2  recordings/External_Microphone_Enhanced_LJ_V1/...
# 3  recordings/External_Microphone_Enhanced_LJ_V1/...
# 4  recordings/External_Microphone_Enhanced_LJ_V1/...
#
#                        throat_small_enhanced_VCTK_V1  \
# 0  recordings/External_Microphone_Enhanced_VCTK_V...
# 1  recordings/External_Microphone_Enhanced_VCTK_V...
# 2  recordings/External_Microphone_Enhanced_VCTK_V...
# 3  recordings/External_Microphone_Enhanced_VCTK_V...
# 4  recordings/External_Microphone_Enhanced_VCTK_V...
#
#                   throat_small_enhanced_UNIVERSAL_V1  \
# 0  recordings/External_Microphone_Enhanced_UNIVER...
# 1  recordings/External_Microphone_Enhanced_UNIVER...
# 2  recordings/External_Microphone_Enhanced_UNIVER...
# 3  recordings/External_Microphone_Enhanced_UNIVER...
# 4  recordings/External_Microphone_Enhanced_UNIVER...
#
#                                   throat_large  \
# 0  recordings/GHW_USB_AUDIO/20251021232813.wav
# 1  recordings/GHW_USB_AUDIO/20251021233140.wav
# 2  recordings/GHW_USB_AUDIO/20251021233208.wav
# 3  recordings/GHW_USB_AUDIO/20251021233250.wav
# 4  recordings/GHW_USB_AUDIO/20251021233319.wav
#
#                                throat_large_enhanced  \
# 0  recordings/GHW_USB_AUDIO_Enhanced/202510212328...
# 1  recordings/GHW_USB_AUDIO_Enhanced/202510212331...
# 2  recordings/GHW_USB_AUDIO_Enhanced/202510212332...
# 3  recordings/GHW_USB_AUDIO_Enhanced/202510212332...
# 4  recordings/GHW_USB_AUDIO_Enhanced/202510212333...
#
#                          throat_large_enhanced_LJ_V1  ... throat_large_score  \
# 0  recordings/GHW_USB_AUDIO_Enhanced_LJ_V1/202510...  ...                  1
# 1  recordings/GHW_USB_AUDIO_Enhanced_LJ_V1/202510...  ...                  1
# 2  recordings/GHW_USB_AUDIO_Enhanced_LJ_V1/202510...  ...                  1
# 3  recordings/GHW_USB_AUDIO_Enhanced_LJ_V1/202510...  ...                  1
# 4  recordings/GHW_USB_AUDIO_Enhanced_LJ_V1/202510...  ...                  1
#
#   throat_large_reason throat_large_enhanced_score  \
# 0         全く別内容。要点不一致                           1
# 1     無進展の意味が崩れ、要点不一致                           1
# 2        主語・述語・内容が不一致                           1
# 3         誤語・否定で意味不一致                           1
# 4           意味不一致・無関係                           1
#
#   throat_large_enhanced_reason throat_large_enhanced_LJ_V1_score  \
# 0                       無関係な内容                                 1
# 1             内容が大きく逸脱し意味が合わない                                 1
# 2                    内容が大きく異なる                                 1
# 3                要点ズレ・語義不明で不一致                                 1
# 4                      意味崩壊・欠落                                 1
#
#   throat_large_enhanced_LJ_V1_reason throat_large_enhanced_VCTK_V1_score  \
# 0                          無関係、要点不一致                                   2
# 1                   意味が通らず主題・要点の伝達失敗                                   1
# 2                         意味不明で要点不一致                                   1
# 3                      別内容の定型文で全く不一致                                   1
# 4                        無関係の挨拶で意味欠落                                   1
#
#   throat_large_enhanced_VCTK_V1_reason  \
# 0                       水はあるが意味不明、産地欠落
# 1                       内容破綻。主題・要点が不一致
# 2                          告発→告白など意味破綻
# 3                          意味破綻し話題も不一致
# 4                          無関係内容で意味不一致
#
#   throat_large_enhanced_UNIVERSAL_V1_score  \
# 0                                        1
# 1                                        3
# 2                                        1
# 3                                        2
# 4                                        1
#
#   throat_large_enhanced_UNIVERSAL_V1_reason
# 0                                  無関係で要点欠落
# 1                          主語誤りだが無進展で終了は伝わる
# 2                                意味不明で要点不一致
# 3                             時間・主題誤りで要点不一致
# 4                               無関係内容で意味不一致
#
# [5 rows x 47 columns]

# %%
df_with_score.to_pickle('throat2air_sklearn_result_hifi-gan.pkl')
